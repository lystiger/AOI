# %% [markdown]
# # Preprocessing
#
# Preview the preprocessing stages on a sample PCB image.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve().parent))

from ml.pipeline.preprocess import preprocess_for_display

sample = Path('../../web/public/mock/pcb-example.png').resolve()
result = preprocess_for_display(sample)
print(result['resized'].shape, result['scale'], result['padding'])
