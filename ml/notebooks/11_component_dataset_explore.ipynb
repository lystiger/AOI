# %% [markdown]
# # Component Dataset Explore
#
# Inspect the cleaned board-level component detection seed dataset.

# %%
import json
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve().parent))

from ml.pipeline.component_train import get_component_data_yaml_path, verify_component_dataset

dataset_root = Path('../data/component_detection_seed').resolve()
print('data.yaml:', get_component_data_yaml_path(dataset_root))
print('split counts:', verify_component_dataset(dataset_root))
manifest = json.loads((dataset_root / 'manifest.json').read_text(encoding='utf-8'))
manifest
