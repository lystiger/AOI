# %% [markdown]
# # Component Training
#
# Launch YOLOv8 training for the component-detection-first baseline.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve().parent))

from ml.pipeline.component_train import train_component_model, verify_component_dataset

dataset_root = Path('../data/component_detection_seed').resolve()
print(verify_component_dataset(dataset_root))
# weights_path = train_component_model(dataset_root=dataset_root, device='cpu', epochs=50)
# print(weights_path)
