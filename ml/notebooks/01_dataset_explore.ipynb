# %% [markdown]
# # Dataset Explore
#
# Inspect the configured component/solder AOI dataset.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve().parent))

from ml.pipeline.dataset import verify, validate_supported_classes, get_data_yaml_path

counts = verify()
print(counts)
print('data.yaml:', get_data_yaml_path())
print('unsupported:', validate_supported_classes())
