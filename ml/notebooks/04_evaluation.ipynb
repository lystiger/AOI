# %% [markdown]
# # Evaluation
#
# Evaluate the latest trained weights and inspect per-class metrics.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve().parent))

from ml.pipeline.evaluate import evaluate

# metrics = evaluate(split='test')
# metrics
