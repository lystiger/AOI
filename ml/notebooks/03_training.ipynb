# %% [markdown]
# # Training
#
# Launch YOLOv8 training after the dataset is configured and verified.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve().parent))

from ml.pipeline.dataset import verify, validate_supported_classes
from ml.pipeline.train import train

print(verify())
print('unsupported:', validate_supported_classes())
# weights_path = train(device='cpu')
# print(weights_path)
